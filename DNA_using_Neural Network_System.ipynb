# %% [markdown]
# <a href="https://colab.research.google.com/github/Scientists-Engineer/Simple_Production/blob/main/DNA_using_Neural%20Network_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DNA and Neural Networks Theory

# %%
# Created by : SE
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from itertools import product
import re
import time
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
import tensorflow as tf
from tensorflow import keras

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
records_df = pd.read_csv("DNA_Datas.csv")
# replace all '-' with N (stands for any nt)
records_df.seq = records_df.seq.str.replace('-', 'N')
print(len(records_df))
records_df.head()
# Out:
# 281
#             id                                                seq  label
# 0  NC_036588.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      0
# 1  NC_014412.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      0
# 2  NC_014413.1  GNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      0
# 3  NC_025890.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      0
# 4  NC_023162.1  NNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN...      0

# %%
records_df.seq = records_df.seq.str.replace('R', 'A')
records_df.seq = records_df.seq.str.replace('Y', 'T')
seq_len = len(records_df.seq[0])
seq_len
# Out:
# 4132

# %%
length = 2449
records_df.seq = records_df.seq.str[:length]
seq_len = len(records_df.seq[0])
seq_len
# Out:
# 2449

# %%
def n_gram(x, word_size=3):
  arr_x = [c for c in x]
  words = tf.strings.ngrams(arr_x, ngram_width=word_size, separator='').numpy()
  words = list(pd.Series(words).apply(lambda b: b.decode('utf-8')))
  return words

records_df["ngram"] = records_df.seq.apply(n_gram)
records_df.head()
# Out:
#             id  ...                                              ngram
# 0  NC_036588.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
# 1  NC_014412.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
# 2  NC_014413.1  ...  [GNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
# 3  NC_025890.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
# 4  NC_023162.1  ...  [NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, NNN, ...
#
# [5 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
xtrain_full, xtest, ytrain_full, ytest = train_test_split(records_df, records_df.label, test_size=0.2, random_state=100, stratify=records_df.label)
xtrain, xval, ytrain, yval = train_test_split(xtrain_full, ytrain_full, test_size=0.2, random_state=100, stratify=ytrain_full)
print("shape of training, validation, test set\n", xtrain.shape, xval.shape, xtest.shape, ytrain.shape, yval.shape, ytest.shape)
# Out:
# shape of training, validation, test set
#  (179, 4) (45, 4) (57, 4) (179,) (45,) (57,)

# %%
word_size = 1
bp_list = 'ACGTN'
vocab = [''.join(p) for p in product(bp_list, repeat=word_size)]
vocab_size = len(bp_list)
print('vocab_size:', vocab_size)
create1gram = keras.layers.experimental.preprocessing.TextVectorization(
  standardize=lambda x: tf.strings.regex_replace(x, '(.)', '\\1 '), ngrams=1
)
create1gram.adapt(vocab)
# Out:
# vocab_size: 5

# %%
def index_preprocess(x):
  x_index = tf.subtract(create1gram(x), 2)
  return x_index, x_index
  
xtrain_seq = tf.data.Dataset.from_tensor_slices(xtrain['seq']).map(index_preprocess).batch(32)
xval_seq = tf.data.Dataset.from_tensor_slices(xval['seq']).map(index_preprocess).batch(32)
xtest_seq = tf.data.Dataset.from_tensor_slices(xtest['seq']).map(index_preprocess).batch(32)

# %%
latent_size = 256

encoder = keras.Sequential([
    keras.Input(shape=(seq_len,)),
    keras.layers.Embedding(seq_len, latent_size),
    keras.layers.LSTM(latent_size, return_sequences=False),
])

decoder = keras.Sequential([
    keras.layers.RepeatVector(seq_len, input_shape=[latent_size]),
    keras.layers.LSTM(latent_size, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(5, activation='softmax'))  # ACTGN
])

recurrent_ae = keras.Sequential([encoder, decoder])
recurrent_ae.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 256)               1152256
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 2449, 5)           526597
# =================================================================
# Total params: 1,678,853
# Trainable params: 1,678,853
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_filepath = '/content/gdrive/My Drive/Colab Notebooks/models/lstm1_viridae_random.32.{epoch:04d}.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_acc',
    mode='max',
    save_best_only=False,
    save_freq=360)
es_cb = keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)

# %%
# Epochs must be 100!

recurrent_ae.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')
# ae_hist = recurrent_ae.fit(xtrain_seq, validation_data=xval_seq, epochs=1000, callbacks=[es_cb, model_checkpoint_callback])
ae_hist = recurrent_ae.fit(xtrain_seq, validation_data=xval_seq, epochs=1, callbacks=[es_cb])
# Out:
# 6/6 [==============================] - 123s 21s/step - loss: 0.9979 - accuracy: 0.8732 - val_loss: 0.6385 - val_accuracy: 0.8991

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
for i in range(1):
  ax1 = axes[0]
  ax2 = axes[1]

  ax1.plot(ae_hist.history['loss'], label='training')
  ax1.plot(ae_hist.history['val_loss'], label='validation')
  ax1.set_title('lstm autoencoder loss')
  ax1.set_xlabel('epoch')
  ax1.set_ylabel('loss')
  ax1.legend(['train', 'validation'], loc='upper left')
  
  ax2.plot(ae_hist.history['accuracy'], label='training')
  ax2.plot(ae_hist.history['val_accuracy'], label='validation')
  ax2.set_title('lstm autoencoder accuracy')
  ax2.set_xlabel('epoch')
  ax2.set_ylabel('accuracy')
  ax2.legend(['train', 'validation'], loc='upper left')
fig.tight_layout()

# %%
xtrain_vec = encoder.predict(xtrain_seq)
xval_vec = encoder.predict(xval_seq)
xtest_vec = encoder.predict(xtest_seq)
print('The shape of xtrain/xval/xtest_seq is', xtrain_vec.shape, xval_vec.shape, xtest_vec.shape)
# Out:
# The shape of xtrain/xval/xtest_seq is (179, 256) (45, 256) (57, 256)

# %%
def plotVec(ax, x, y, title="title"):
  scatter = ax.scatter(x[:, 0], x[:, 1], c=y, 
             cmap=matplotlib.colors.ListedColormap(["red", "blue", "yellow"]))
  ax.set_title(title)
  ax.legend(*scatter.legend_elements(), loc=0, title="Classes")

# %%
xtrain_tsne = TSNE(n_components=2, metric="cosine").fit_transform(xtrain_vec)
xval_tsne = TSNE(n_components=2, metric="cosine").fit_transform(xval_vec)
xtest_tsne = TSNE(n_components=2, metric="cosine").fit_transform(xtest_vec)

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
plotVec(axes[0], xtrain_tsne, ytrain, title="TSNE, training")
plotVec(axes[1], xval_tsne, yval, title="TSNE, validation")
plotVec(axes[2], xtest_tsne, ytest, title="TSNE, test")
fig.tight_layout()

# %%
model = keras.models.Sequential([
  keras.layers.Dense(256, activation="relu", input_shape=[latent_size]),
  keras.layers.Dropout(0.2),
  keras.layers.Dense(128, activation="relu"),
  keras.layers.Dropout(0.2),
  keras.layers.Dense(64, activation="relu"), 
  keras.layers.Dropout(0.2),    
  keras.layers.Dense(32, activation="relu"), 
  keras.layers.Dropout(0.2),    
  keras.layers.Dense(16, activation="relu"), 
  keras.layers.Dropout(0.2),    
  keras.layers.Dense(1, activation="sigmoid")                               
])
model.compile(keras.optimizers.SGD(momentum=0.9), loss=keras.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model_hist = model.fit(xtrain_vec, ytrain, validation_data=(xval_vec, yval), epochs=100, callbacks=[es_cb])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6753 - accuracy: 0.6034 - val_loss: 0.6354 - val_accuracy: 0.7111
# Epoch 2/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6651 - accuracy: 0.6089 - val_loss: 0.6333 - val_accuracy: 0.7111
# Epoch 3/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6697 - accuracy: 0.6480 - val_loss: 0.6322 - val_accuracy: 0.7111
# Epoch 4/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6515 - accuracy: 0.6257 - val_loss: 0.6325 - val_accuracy: 0.7111
# Epoch 5/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6602 - accuracy: 0.5978 - val_loss: 0.6311 - val_accuracy: 0.7111
# Epoch 6/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6835 - accuracy: 0.5922 - val_loss: 0.6446 - val_accuracy: 0.7333
# Epoch 7/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6633 - accuracy: 0.5978 - val_loss: 0.6359 - val_accuracy: 0.7111
# Epoch 8/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6827 - accuracy: 0.6369 - val_loss: 0.6275 - val_accuracy: 0.7111
# Epoch 9/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6619 - accuracy: 0.6369 - val_loss: 0.6278 - val_accuracy: 0.7111
# Epoch 10/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6614 - accuracy: 0.6369 - val_loss: 0.6354 - val_accuracy: 0.7111
# Epoch 11/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6531 - accuracy: 0.6257 - val_loss: 0.6310 - val_accuracy: 0.7111
# Epoch 12/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6448 - accuracy: 0.6592 - val_loss: 0.6241 - val_accuracy: 0.7111
# Epoch 13/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6271 - accuracy: 0.6927 - val_loss: 0.6196 - val_accuracy: 0.7111
# Epoch 14/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6698 - accuracy: 0.6201 - val_loss: 0.6202 - val_accuracy: 0.7111
# Epoch 15/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6494 - accuracy: 0.6480 - val_loss: 0.6164 - val_accuracy: 0.7111
# Epoch 16/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6461 - accuracy: 0.6313 - val_loss: 0.6210 - val_accuracy: 0.7111
# Epoch 17/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6403 - accuracy: 0.6145 - val_loss: 0.6139 - val_accuracy: 0.7111
# Epoch 18/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6477 - accuracy: 0.6536 - val_loss: 0.6101 - val_accuracy: 0.7111
# Epoch 19/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6820 - accuracy: 0.6313 - val_loss: 0.6210 - val_accuracy: 0.7111
# Epoch 20/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6561 - accuracy: 0.5922 - val_loss: 0.6199 - val_accuracy: 0.7111
# Epoch 21/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6642 - accuracy: 0.5866 - val_loss: 0.6093 - val_accuracy: 0.7111
# Epoch 22/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6751 - accuracy: 0.6201 - val_loss: 0.6085 - val_accuracy: 0.7111
# Epoch 23/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6371 - accuracy: 0.6257 - val_loss: 0.6114 - val_accuracy: 0.7111
# Epoch 24/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6704 - accuracy: 0.6034 - val_loss: 0.6204 - val_accuracy: 0.7333
# Epoch 25/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6375 - accuracy: 0.6592 - val_loss: 0.6115 - val_accuracy: 0.7111
# Epoch 26/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6533 - accuracy: 0.6425 - val_loss: 0.6067 - val_accuracy: 0.7111
# Epoch 27/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6431 - accuracy: 0.6816 - val_loss: 0.6083 - val_accuracy: 0.7111
# Epoch 28/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6399 - accuracy: 0.6313 - val_loss: 0.6063 - val_accuracy: 0.7111
# Epoch 29/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6809 - accuracy: 0.5866 - val_loss: 0.6032 - val_accuracy: 0.7111
# Epoch 30/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6579 - accuracy: 0.6089 - val_loss: 0.6142 - val_accuracy: 0.7111
# Epoch 31/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6592 - accuracy: 0.6034 - val_loss: 0.6042 - val_accuracy: 0.7111
# Epoch 32/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6257 - accuracy: 0.6816 - val_loss: 0.6022 - val_accuracy: 0.7111
# Epoch 33/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6462 - accuracy: 0.6704 - val_loss: 0.6071 - val_accuracy: 0.7111
# Epoch 34/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6472 - accuracy: 0.6201 - val_loss: 0.6058 - val_accuracy: 0.7111
# Epoch 35/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6197 - accuracy: 0.6760 - val_loss: 0.5974 - val_accuracy: 0.7111
# Epoch 36/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6647 - accuracy: 0.6480 - val_loss: 0.6046 - val_accuracy: 0.7111
# Epoch 37/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6507 - accuracy: 0.6089 - val_loss: 0.6051 - val_accuracy: 0.7111
# Epoch 38/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6289 - accuracy: 0.5922 - val_loss: 0.5968 - val_accuracy: 0.7111
# Epoch 39/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6495 - accuracy: 0.6872 - val_loss: 0.5949 - val_accuracy: 0.7111
# Epoch 40/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6585 - accuracy: 0.6257 - val_loss: 0.6054 - val_accuracy: 0.7333
# Epoch 41/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6512 - accuracy: 0.6145 - val_loss: 0.5960 - val_accuracy: 0.7111
# Epoch 42/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6428 - accuracy: 0.6089 - val_loss: 0.5957 - val_accuracy: 0.7111
# Epoch 43/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6404 - accuracy: 0.6369 - val_loss: 0.5943 - val_accuracy: 0.7111
# Epoch 44/100
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6534 - accuracy: 0.6369 - val_loss: 0.5975 - val_accuracy: 0.7111
# Epoch 45/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6463 - accuracy: 0.6089 - val_loss: 0.6006 - val_accuracy: 0.7111
# Epoch 46/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6346 - accuracy: 0.6872 - val_loss: 0.5932 - val_accuracy: 0.7111
# Epoch 47/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6610 - accuracy: 0.6257 - val_loss: 0.5943 - val_accuracy: 0.7111
# Epoch 48/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6261 - accuracy: 0.6313 - val_loss: 0.5931 - val_accuracy: 0.7111
# Epoch 49/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6101 - accuracy: 0.7039 - val_loss: 0.5906 - val_accuracy: 0.7111
# Epoch 50/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6348 - accuracy: 0.6480 - val_loss: 0.5916 - val_accuracy: 0.7111
# Epoch 51/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6130 - accuracy: 0.6704 - val_loss: 0.5919 - val_accuracy: 0.7111
# Epoch 52/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6247 - accuracy: 0.6816 - val_loss: 0.5862 - val_accuracy: 0.7111
# Epoch 53/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6528 - accuracy: 0.6201 - val_loss: 0.5848 - val_accuracy: 0.7111
# Epoch 54/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6082 - accuracy: 0.6760 - val_loss: 0.5847 - val_accuracy: 0.7111
# Epoch 55/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6574 - accuracy: 0.6257 - val_loss: 0.5979 - val_accuracy: 0.7556
# Epoch 56/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6318 - accuracy: 0.6704 - val_loss: 0.5829 - val_accuracy: 0.7111
# Epoch 57/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6148 - accuracy: 0.6369 - val_loss: 0.5832 - val_accuracy: 0.7111
# Epoch 58/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6462 - accuracy: 0.6313 - val_loss: 0.5816 - val_accuracy: 0.7111
# Epoch 59/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6585 - accuracy: 0.6369 - val_loss: 0.5906 - val_accuracy: 0.7111
# Epoch 60/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6409 - accuracy: 0.5978 - val_loss: 0.5897 - val_accuracy: 0.7111
# Epoch 61/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6157 - accuracy: 0.6201 - val_loss: 0.5863 - val_accuracy: 0.7111
# Epoch 62/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6143 - accuracy: 0.6480 - val_loss: 0.5814 - val_accuracy: 0.7111
# Epoch 63/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6388 - accuracy: 0.6480 - val_loss: 0.5814 - val_accuracy: 0.7111
# Epoch 64/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6222 - accuracy: 0.6313 - val_loss: 0.5798 - val_accuracy: 0.7111
# Epoch 65/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6744 - accuracy: 0.5978 - val_loss: 0.5804 - val_accuracy: 0.7111
# Epoch 66/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6286 - accuracy: 0.6313 - val_loss: 0.5822 - val_accuracy: 0.7111
# Epoch 67/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6316 - accuracy: 0.6480 - val_loss: 0.5820 - val_accuracy: 0.7111
# Epoch 68/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6417 - accuracy: 0.6536 - val_loss: 0.5885 - val_accuracy: 0.7111
# Epoch 69/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6343 - accuracy: 0.5866 - val_loss: 0.5805 - val_accuracy: 0.7111
# Epoch 70/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6328 - accuracy: 0.6480 - val_loss: 0.5780 - val_accuracy: 0.7111
# Epoch 71/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6256 - accuracy: 0.6425 - val_loss: 0.5778 - val_accuracy: 0.7111
# Epoch 72/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6147 - accuracy: 0.6927 - val_loss: 0.5762 - val_accuracy: 0.7111
# Epoch 73/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6286 - accuracy: 0.6201 - val_loss: 0.5755 - val_accuracy: 0.7111
# Epoch 74/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6231 - accuracy: 0.6257 - val_loss: 0.5857 - val_accuracy: 0.7333
# Epoch 75/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6396 - accuracy: 0.6480 - val_loss: 0.5732 - val_accuracy: 0.7111
# Epoch 76/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6368 - accuracy: 0.6145 - val_loss: 0.5730 - val_accuracy: 0.7111
# Epoch 77/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6161 - accuracy: 0.6704 - val_loss: 0.5778 - val_accuracy: 0.7111
# Epoch 78/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6178 - accuracy: 0.6425 - val_loss: 0.5716 - val_accuracy: 0.7111
# Epoch 79/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6568 - accuracy: 0.6145 - val_loss: 0.5767 - val_accuracy: 0.7111
# Epoch 80/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6133 - accuracy: 0.6480 - val_loss: 0.5730 - val_accuracy: 0.7111
# Epoch 81/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6514 - accuracy: 0.6145 - val_loss: 0.5724 - val_accuracy: 0.7111
# Epoch 82/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6371 - accuracy: 0.6034 - val_loss: 0.5742 - val_accuracy: 0.7111
# Epoch 83/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6125 - accuracy: 0.6816 - val_loss: 0.5708 - val_accuracy: 0.7111
# Epoch 84/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6250 - accuracy: 0.6201 - val_loss: 0.5718 - val_accuracy: 0.7111
# Epoch 85/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6266 - accuracy: 0.6760 - val_loss: 0.5725 - val_accuracy: 0.7111
# Epoch 86/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6325 - accuracy: 0.6089 - val_loss: 0.5706 - val_accuracy: 0.7111
# Epoch 87/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6093 - accuracy: 0.6592 - val_loss: 0.5659 - val_accuracy: 0.7111
# Epoch 88/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6160 - accuracy: 0.6816 - val_loss: 0.5637 - val_accuracy: 0.7111
# Epoch 89/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6242 - accuracy: 0.6592 - val_loss: 0.5682 - val_accuracy: 0.7111
# Epoch 90/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6226 - accuracy: 0.6201 - val_loss: 0.5681 - val_accuracy: 0.7111
# Epoch 91/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6678 - accuracy: 0.6089 - val_loss: 0.5625 - val_accuracy: 0.7111
# Epoch 92/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6125 - accuracy: 0.6872 - val_loss: 0.5734 - val_accuracy: 0.7111
# Epoch 93/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6378 - accuracy: 0.5642 - val_loss: 0.5690 - val_accuracy: 0.7111
# Epoch 94/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6286 - accuracy: 0.6760 - val_loss: 0.5658 - val_accuracy: 0.7111
# Epoch 95/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6111 - accuracy: 0.6648 - val_loss: 0.5643 - val_accuracy: 0.7111
# Epoch 96/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6019 - accuracy: 0.6704 - val_loss: 0.5646 - val_accuracy: 0.7111
# Epoch 97/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6510 - accuracy: 0.6089 - val_loss: 0.5659 - val_accuracy: 0.7111
# Epoch 98/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6156 - accuracy: 0.6592 - val_loss: 0.5659 - val_accuracy: 0.7111
# Epoch 99/100
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6136 - accuracy: 0.6536 - val_loss: 0.5609 - val_accuracy: 0.7111
# Epoch 100/100
# 6/6 [==============================] - 0s 5ms/step - loss: 0.5975 - accuracy: 0.6872 - val_loss: 0.5602 - val_accuracy: 0.7111

# %%
def eval_model(model, x, true_label, ds_name="Training"):
  loss, acc = model.evaluate(x, true_label, verbose=0)
  print("{} Dataset: loss = {} and acccuracy = {}".format(ds_name, np.round(loss, 3), np.round(acc, 3)))

# %%
eval_model(model, xtrain_vec, ytrain, "Training")
eval_model(model, xval_vec, yval, "Validation")
eval_model(model, xtest_vec, ytest, "Test")
# Out:
# Training Dataset: loss = 0.594 and acccuracy = 0.687
# Validation Dataset: loss = 0.56 and acccuracy = 0.711
# Test Dataset: loss = 0.616 and acccuracy = 0.667

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
for i in range(1):
  ax1 = axes[0]
  ax2 = axes[1]

  ax1.plot(model_hist.history['loss'], label='training')
  ax1.plot(model_hist.history['val_loss'], label='validation')
  ax1.set_title('NN Multiclassification loss')
  ax1.set_xlabel('epoch')
  ax1.set_ylabel('loss')
  ax1.legend(['train', 'validation'], loc='upper left')
  
  ax2.plot(model_hist.history['accuracy'], label='training')
  ax2.plot(model_hist.history['val_accuracy'], label='validation')
  ax2.set_title('NN Multiclassification accuracy')
  ax2.set_xlabel('epoch')
  ax2.set_ylabel('accuracy')
  ax2.legend(['train', 'validation'], loc='upper left')
fig.tight_layout()
